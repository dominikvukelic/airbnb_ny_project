# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import os

# %% [markdown]
# ### Importing data

# %%
# Specify the relative path to the starting CSV file from the current working directory
relative_path = os.path.join('..', 'starting_file', 'Airbnb_Open_Data.csv')

# Construct the absolute path
absolute_path = os.path.abspath(relative_path)

# Read the CSV file into a DataFrame
df = pd.read_csv(absolute_path, low_memory=False)

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        service fee minimum nights number of reviews last review  \
# 0            $193            10.0               9.0  10/19/2021
# 1             $28            30.0              45.0   5/21/2022
# 2            $124             3.0               0.0         NaN
# 3             $74            30.0             270.0    7/5/2019
# 4             $41            10.0               9.0  11/19/2018
# ...            ...            ...               ...         ...
# 102594       $169             1.0               0.0         NaN
# 102595       $167             1.0               1.0    7/6/2015
# 102596       $198             3.0               0.0         NaN
# 102597       $109             2.0               5.0  10/11/2015
# 102598       $206             1.0               0.0         NaN
#
#         reviews per month review rate number calculated host listings count  \
# 0                    0.21                4.0                            6.0
# 1                    0.38                4.0                            2.0
# 2                     NaN                5.0                            1.0
# 3                    4.64                4.0                            1.0
# 4                    0.10                3.0                            1.0
# ...                   ...                ...                            ...
# 102594                NaN                3.0                            1.0
# 102595               0.02                2.0                            2.0
# 102596                NaN                5.0                            1.0
# 102597               0.10                3.0                            1.0
# 102598                NaN                3.0                            1.0
#
#         availability 365                                        house_rules  \
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
#        license
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 102594     NaN
# 102595     NaN
# 102596     NaN
# 102597     NaN
# 102598     NaN
#
# [102599 rows x 26 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Data cleaning and preparing for analysis

# %% [markdown]
# #### Checking DataFrame shape

# %%
df.shape
# Out:
# (102599, 26)

# %% [markdown]
# #### Checking for null values in a whole DataFrame

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# #### Counting how many null values each column has

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                     0
# NAME                                 250
# host id                                0
# host_identity_verified               289
# host name                            406
# neighbourhood group                   29
# neighbourhood                         16
# lat                                    8
# long                                   8
# country                              532
# country code                         131
# instant_bookable                     105
# cancellation_policy                   76
# room type                              0
# Construction year                    214
# price                                247
# service fee                          273
# minimum nights                       409
# number of reviews                    183
# last review                        15893
# reviews per month                  15879
# review rate number                   326
# calculated host listings count       319
# availability 365                     448
# house_rules                        52131
# license                           102597
# dtype: int64

# %% [markdown]
# #### Checking licence column rows with actual value

# %%
# Extract values from 'license' column where the value is not NaN
non_nan_license_values = df.loc[df['license'].notna(), 'license']

# Print the result
print("Values in 'license' column where the value is not NaN:")
print(non_nan_license_values)
# Out:
# Values in 'license' column where the value is not NaN:
# 11114    41662/AL
# 72947    41662/AL
# Name: license, dtype: object

# %% [markdown]
# #### Changing null values in 'license' column to 'No Licence Info'

# %%
df['license'] = df['license'].fillna('No Licence Info')

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        service fee minimum nights number of reviews last review  \
# 0            $193            10.0               9.0  10/19/2021
# 1             $28            30.0              45.0   5/21/2022
# 2            $124             3.0               0.0         NaN
# 3             $74            30.0             270.0    7/5/2019
# 4             $41            10.0               9.0  11/19/2018
# ...            ...            ...               ...         ...
# 102594       $169             1.0               0.0         NaN
# 102595       $167             1.0               1.0    7/6/2015
# 102596       $198             3.0               0.0         NaN
# 102597       $109             2.0               5.0  10/11/2015
# 102598       $206             1.0               0.0         NaN
#
#         reviews per month review rate number calculated host listings count  \
# 0                    0.21                4.0                            6.0
# 1                    0.38                4.0                            2.0
# 2                     NaN                5.0                            1.0
# 3                    4.64                4.0                            1.0
# 4                    0.10                3.0                            1.0
# ...                   ...                ...                            ...
# 102594                NaN                3.0                            1.0
# 102595               0.02                2.0                            2.0
# 102596                NaN                5.0                            1.0
# 102597               0.10                3.0                            1.0
# 102598                NaN                3.0                            1.0
#
#         availability 365                                        house_rules  \
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
#                 license
# 0       No Licence Info
# 1       No Licence Info
# 2       No Licence Info
# 3       No Licence Info
# 4       No Licence Info
# ...                 ...
# 102594  No Licence Info
# 102595  No Licence Info
# 102596  No Licence Info
# 102597  No Licence Info
# 102598  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Checking how many different values country column has

# %%
unique_country_count = df['country'].nunique()

print("Number of unique values in 'country' column:", unique_country_count)
# Out:
# Number of unique values in 'country' column: 1

# %% [markdown]
# #### Changing NaN values in 'country' column to 'United States'

# %%
df['country'] = df['country'].fillna('United States')

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country  ...  \
# 0                Kensington  40.64749 -73.97237  United States  ...
# 1                   Midtown  40.75362 -73.98377  United States  ...
# 2                    Harlem  40.80902 -73.94190  United States  ...
# 3              Clinton Hill  40.68514 -73.95976  United States  ...
# 4               East Harlem  40.79851 -73.94399  United States  ...
# ...                     ...       ...       ...            ...  ...
# 102594         Williamsburg  40.70862 -73.94651  United States  ...
# 102595  Morningside Heights  40.80460 -73.96545  United States  ...
# 102596           Park Slope  40.67505 -73.98045  United States  ...
# 102597     Long Island City  40.74989 -73.93777  United States  ...
# 102598      Upper West Side  40.76807 -73.98342  United States  ...
#
#        service fee minimum nights number of reviews last review  \
# 0            $193            10.0               9.0  10/19/2021
# 1             $28            30.0              45.0   5/21/2022
# 2            $124             3.0               0.0         NaN
# 3             $74            30.0             270.0    7/5/2019
# 4             $41            10.0               9.0  11/19/2018
# ...            ...            ...               ...         ...
# 102594       $169             1.0               0.0         NaN
# 102595       $167             1.0               1.0    7/6/2015
# 102596       $198             3.0               0.0         NaN
# 102597       $109             2.0               5.0  10/11/2015
# 102598       $206             1.0               0.0         NaN
#
#         reviews per month review rate number calculated host listings count  \
# 0                    0.21                4.0                            6.0
# 1                    0.38                4.0                            2.0
# 2                     NaN                5.0                            1.0
# 3                    4.64                4.0                            1.0
# 4                    0.10                3.0                            1.0
# ...                   ...                ...                            ...
# 102594                NaN                3.0                            1.0
# 102595               0.02                2.0                            2.0
# 102596                NaN                5.0                            1.0
# 102597               0.10                3.0                            1.0
# 102598                NaN                3.0                            1.0
#
#         availability 365                                        house_rules  \
# 0                  286.0  Clean up and treat the home the way you'd like...
# 1                  228.0  Pet friendly but please confirm with me if the...
# 2                  352.0  I encourage you to use my kitchen, cooking and...
# 3                  322.0                                                NaN
# 4                  289.0  Please no smoking in the house, porch or on th...
# ...                  ...                                                ...
# 102594             227.0  No Smoking No Parties or Events of any kind Pl...
# 102595             395.0  House rules: Guests agree to the following ter...
# 102596             342.0                                                NaN
# 102597             386.0                                                NaN
# 102598              69.0                                                NaN
#
#                 license
# 0       No Licence Info
# 1       No Licence Info
# 2       No Licence Info
# 3       No Licence Info
# 4       No Licence Info
# ...                 ...
# 102594  No Licence Info
# 102595  No Licence Info
# 102596  No Licence Info
# 102597  No Licence Info
# 102598  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Veryfing that there are no null values in country column anymore

# %%
nan_count_in_country = df['country'].isna().sum()
print(nan_count_in_country)
# Out:
# 0

# %% [markdown]
# #### Viewing all columns

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# #### Counting null values for each column again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                250
# host id                               0
# host_identity_verified              289
# host name                           406
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                               0
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service fee                         273
# minimum nights                      409
# number of reviews                   183
# last review                       15893
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       52131
# license                               0
# dtype: int64

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594            False            flexible     Private room
# 102595             True            moderate     Private room
# 102596             True            moderate     Private room
# 102597             True              strict  Entire home/apt
# 102598            False            flexible  Entire home/apt
#
#         Construction year    price service fee  minimum nights  \
# 0                  2020.0    $966        $193             10.0
# 1                  2007.0    $142         $28             30.0
# 2                  2005.0    $620        $124              3.0
# 3                  2005.0    $368         $74             30.0
# 4                  2009.0    $204         $41             10.0
# ...                   ...      ...         ...             ...
# 102594             2003.0    $844        $169              1.0
# 102595             2016.0    $837        $167              1.0
# 102596             2009.0    $988        $198              3.0
# 102597             2015.0    $546        $109              2.0
# 102598             2010.0  $1,032        $206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Changing null values in 'service fee' column to 'No Info'

# %%
df['service fee'] = df['service fee'].fillna('No Info')

# %%
nan_count_in_service_fee = df['service fee'].isna().sum()
print(nan_count_in_service_fee)
# Out:
# 0

# %% [markdown]
# #### Removing $ from service fee column rows and converting numbers to int value

# %%
# Remove '$' and convert to integers if the value contains '$', otherwise keep the value
df['service fee'] = df['service fee'].replace('[\$,]', '', regex=True)

# Convert values to integers, keeping 'No Info' as a string
df['service fee'] = pd.to_numeric(df['service fee'], errors='ignore', downcast='integer')

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594            False            flexible     Private room
# 102595             True            moderate     Private room
# 102596             True            moderate     Private room
# 102597             True              strict  Entire home/apt
# 102598            False            flexible  Entire home/apt
#
#         Construction year    price service fee  minimum nights  \
# 0                  2020.0    $966         193             10.0
# 1                  2007.0    $142          28             30.0
# 2                  2005.0    $620         124              3.0
# 3                  2005.0    $368          74             30.0
# 4                  2009.0    $204          41             10.0
# ...                   ...      ...         ...             ...
# 102594             2003.0    $844         169              1.0
# 102595             2016.0    $837         167              1.0
# 102596             2009.0    $988         198              3.0
# 102597             2015.0    $546         109              2.0
# 102598             2010.0  $1,032         206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Renaming service fee column to service_fee_in_$

# %%
df = df.rename(columns={'service fee': 'service_fee_in_$'})

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                 False              strict     Private room
# 1                 False            moderate  Entire home/apt
# 2                  True            flexible     Private room
# 3                  True            moderate  Entire home/apt
# 4                 False            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594            False            flexible     Private room
# 102595             True            moderate     Private room
# 102596             True            moderate     Private room
# 102597             True              strict  Entire home/apt
# 102598            False            flexible  Entire home/apt
#
#         Construction year    price service_fee_in_$  minimum nights  \
# 0                  2020.0    $966              193             10.0
# 1                  2007.0    $142               28             30.0
# 2                  2005.0    $620              124              3.0
# 3                  2005.0    $368               74             30.0
# 4                  2009.0    $204               41             10.0
# ...                   ...      ...              ...             ...
# 102594             2003.0    $844              169              1.0
# 102595             2016.0    $837              167              1.0
# 102596             2009.0    $988              198              3.0
# 102597             2015.0    $546              109              2.0
# 102598             2010.0  $1,032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Changing values in instant_bookable column from boolean to string yes/no

# %%
df['instant_bookable'] = df['instant_bookable'].replace({True: 'yes', False: 'no'})

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                    NaN        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood       lat      long        country country code  \
# 0                Kensington  40.64749 -73.97237  United States           US
# 1                   Midtown  40.75362 -73.98377  United States           US
# 2                    Harlem  40.80902 -73.94190  United States           US
# 3              Clinton Hill  40.68514 -73.95976  United States           US
# 4               East Harlem  40.79851 -73.94399  United States           US
# ...                     ...       ...       ...            ...          ...
# 102594         Williamsburg  40.70862 -73.94651  United States           US
# 102595  Morningside Heights  40.80460 -73.96545  United States           US
# 102596           Park Slope  40.67505 -73.98045  United States           US
# 102597     Long Island City  40.74989 -73.93777  United States           US
# 102598      Upper West Side  40.76807 -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         Construction year    price service_fee_in_$  minimum nights  \
# 0                  2020.0    $966              193             10.0
# 1                  2007.0    $142               28             30.0
# 2                  2005.0    $620              124              3.0
# 3                  2005.0    $368               74             30.0
# 4                  2009.0    $204               41             10.0
# ...                   ...      ...              ...             ...
# 102594             2003.0    $844              169              1.0
# 102595             2016.0    $837              167              1.0
# 102596             2009.0    $988              198              3.0
# 102597             2015.0    $546              109              2.0
# 102598             2010.0  $1,032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102599 rows x 26 columns]

# %% [markdown]
# #### Counting null values in all columns

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                250
# host id                               0
# host_identity_verified              289
# host name                           406
# neighbourhood group                  29
# neighbourhood                        16
# lat                                   8
# long                                  8
# country                               0
# country code                        131
# instant_bookable                    105
# cancellation_policy                  76
# room type                             0
# Construction year                   214
# price                               247
# service_fee_in_$                      0
# minimum nights                      409
# number of reviews                   183
# last review                       15893
# reviews per month                 15879
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       52131
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping all rows where price is null

# %%
df.dropna(subset=['price'], inplace=True)

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                247
# host id                               0
# host_identity_verified              285
# host name                           401
# neighbourhood group                  28
# neighbourhood                        15
# lat                                   8
# long                                  8
# country                               0
# country code                        126
# instant_bookable                    100
# cancellation_policy                  71
# room type                             0
# Construction year                   210
# price                                 0
# service_fee_in_$                      0
# minimum nights                      409
# number of reviews                   183
# last review                       15867
# reviews per month                 15852
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       51996
# license                               0
# dtype: int64

# %% [markdown]
# #### Changing null values in 'host_identity_verified' column to 'No Info'

# %%
df['host_identity_verified'] = df['host_identity_verified'].fillna('No Info')

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                247
# host id                               0
# host_identity_verified                0
# host name                           401
# neighbourhood group                  28
# neighbourhood                        15
# lat                                   8
# long                                  8
# country                               0
# country code                        126
# instant_bookable                    100
# cancellation_policy                  71
# room type                             0
# Construction year                   210
# price                                 0
# service_fee_in_$                      0
# minimum nights                      409
# number of reviews                   183
# last review                       15867
# reviews per month                 15852
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       51996
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping all rows where lat and long are null

# %%
df.dropna(subset=['lat', 'long'], inplace=True)

# %% [markdown]
# #### Renaming columns from 'lat' and 'long' to 'latitude' and 'longitude'

# %%
df = df.rename(columns={'lat': 'latitude', 'long': 'longitude'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                247
# host id                               0
# host_identity_verified                0
# host name                           401
# neighbourhood group                  28
# neighbourhood                        15
# latitude                              0
# longitude                             0
# country                               0
# country code                        126
# instant_bookable                    100
# cancellation_policy                  71
# room type                             0
# Construction year                   209
# price                                 0
# service_fee_in_$                      0
# minimum nights                      409
# number of reviews                   183
# last review                       15866
# reviews per month                 15851
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       51994
# license                               0
# dtype: int64

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         Construction year    price service_fee_in_$  minimum nights  \
# 0                  2020.0    $966              193             10.0
# 1                  2007.0    $142               28             30.0
# 2                  2005.0    $620              124              3.0
# 3                  2005.0    $368               74             30.0
# 4                  2009.0    $204               41             10.0
# ...                   ...      ...              ...             ...
# 102594             2003.0    $844              169              1.0
# 102595             2016.0    $837              167              1.0
# 102596             2009.0    $988              198              3.0
# 102597             2015.0    $546              109              2.0
# 102598             2010.0  $1,032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102344 rows x 26 columns]

# %% [markdown]
# #### Changing null values in 'host name' column to 'No Info'

# %%
df['host name'] = df['host name'].fillna('No Info')

# %% [markdown]
# #### Renaming host name column to host_name

# %%
df = df.rename(columns={'host name': 'host_name'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                247
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood group                  28
# neighbourhood                        15
# latitude                              0
# longitude                             0
# country                               0
# country code                        126
# instant_bookable                    100
# cancellation_policy                  71
# room type                             0
# Construction year                   209
# price                                 0
# service_fee_in_$                      0
# minimum nights                      409
# number of reviews                   183
# last review                       15866
# reviews per month                 15851
# review rate number                  326
# calculated host listings count      319
# availability 365                    448
# house_rules                       51994
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping all rows where neighbourhood group  is null

# %%
df.dropna(subset=['neighbourhood group'], inplace=True)

# %% [markdown]
# #### Renaming neighbourhood group column to neighbourhood_group

# %%
df = df.rename(columns={'neighbourhood group': 'neighbourhood_group'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                245
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        15
# latitude                              0
# longitude                             0
# country                               0
# country code                        125
# instant_bookable                     99
# cancellation_policy                  70
# room type                             0
# Construction year                   204
# price                                 0
# service_fee_in_$                      0
# minimum nights                      408
# number of reviews                   183
# last review                       15862
# reviews per month                 15849
# review rate number                  324
# calculated host listings count      319
# availability 365                    437
# house_rules                       51987
# license                               0
# dtype: int64

# %% [markdown]
# #### Changing NaN values in 'country code' column to 'US'

# %%
df['country code'] = df['country code'].fillna('US')

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         Construction year    price service_fee_in_$  minimum nights  \
# 0                  2020.0    $966              193             10.0
# 1                  2007.0    $142               28             30.0
# 2                  2005.0    $620              124              3.0
# 3                  2005.0    $368               74             30.0
# 4                  2009.0    $204               41             10.0
# ...                   ...      ...              ...             ...
# 102594             2003.0    $844              169              1.0
# 102595             2016.0    $837              167              1.0
# 102596             2009.0    $988              198              3.0
# 102597             2015.0    $546              109              2.0
# 102598             2010.0  $1,032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability 365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [102316 rows x 26 columns]

# %% [markdown]
# #### Renaming country code column to country_code

# %%
df = df.rename(columns={'country code': 'country_code'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                245
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        15
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                     99
# cancellation_policy                  70
# room type                             0
# Construction year                   204
# price                                 0
# service_fee_in_$                      0
# minimum nights                      408
# number of reviews                   183
# last review                       15862
# reviews per month                 15849
# review rate number                  324
# calculated host listings count      319
# availability 365                    437
# house_rules                       51987
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping all rows where availability 365 is null

# %%
df.dropna(subset=['availability 365'], inplace=True)

# %% [markdown]
# #### Renaming availability 365 column to availability_365

# %%
df = df.rename(columns={'availability 365': 'availability_365'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                227
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        14
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                     92
# cancellation_policy                  63
# room type                             0
# Construction year                   186
# price                                 0
# service_fee_in_$                      0
# minimum nights                      386
# number of reviews                   129
# last review                       15596
# reviews per month                 15588
# review rate number                  310
# calculated host listings count      319
# availability_365                      0
# house_rules                       51741
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping all rows where minimum nights is null

# %%
df.dropna(subset=['minimum nights'], inplace=True)

# %% [markdown]
# #### Renaming minimum nights column to minimum_nights

# %%
df = df.rename(columns={'minimum nights': 'minimum_nights'})

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                221
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        13
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                     84
# cancellation_policy                  63
# room type                             0
# Construction year                   180
# price                                 0
# service_fee_in_$                      0
# minimum_nights                        0
# number of reviews                   127
# last review                       15534
# reviews per month                 15533
# review rate number                  297
# calculated host listings count      319
# availability_365                      0
# house_rules                       51555
# license                               0
# dtype: int64

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         Construction year    price service_fee_in_$  minimum_nights  \
# 0                  2020.0    $966              193             10.0
# 1                  2007.0    $142               28             30.0
# 2                  2005.0    $620              124              3.0
# 3                  2005.0    $368               74             30.0
# 4                  2009.0    $204               41             10.0
# ...                   ...      ...              ...             ...
# 102594             2003.0    $844              169              1.0
# 102595             2016.0    $837              167              1.0
# 102596             2009.0    $988              198              3.0
# 102597             2015.0    $546              109              2.0
# 102598             2010.0  $1,032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability_365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [101493 rows x 26 columns]

# %% [markdown]
# #### Removing $ from price column rows

# %%
# Remove '$' and convert to integers if the value contains '$', otherwise keep the value
df['price'] = df['price'].replace('[\$,]', '', regex=True)

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         Construction year  price service_fee_in_$  minimum_nights  \
# 0                  2020.0   966              193             10.0
# 1                  2007.0   142               28             30.0
# 2                  2005.0   620              124              3.0
# 3                  2005.0   368               74             30.0
# 4                  2009.0   204               41             10.0
# ...                   ...    ...              ...             ...
# 102594             2003.0   844              169              1.0
# 102595             2016.0   837              167              1.0
# 102596             2009.0   988              198              3.0
# 102597             2015.0   546              109              2.0
# 102598             2010.0  1032              206              1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability_365  \
# 0                                  6.0             286.0
# 1                                  2.0             228.0
# 2                                  1.0             352.0
# 3                                  1.0             322.0
# 4                                  1.0             289.0
# ...                                ...               ...
# 102594                             1.0             227.0
# 102595                             2.0             395.0
# 102596                             1.0             342.0
# 102597                             1.0             386.0
# 102598                             1.0              69.0
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [101493 rows x 26 columns]

# %% [markdown]
# #### Renaming price column to price_in_$

# %%
df = df.rename(columns={'price': 'price_in_$'})

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101493 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101493 non-null  int64
#  1   NAME                            101272 non-null  object
#  2   host id                         101493 non-null  int64
#  3   host_identity_verified          101493 non-null  object
#  4   host_name                       101493 non-null  object
#  5   neighbourhood_group             101493 non-null  object
#  6   neighbourhood                   101480 non-null  object
#  7   latitude                        101493 non-null  float64
#  8   longitude                       101493 non-null  float64
#  9   country                         101493 non-null  object
#  10  country_code                    101493 non-null  object
#  11  instant_bookable                101409 non-null  object
#  12  cancellation_policy             101430 non-null  object
#  13  room type                       101493 non-null  object
#  14  Construction year               101313 non-null  float64
#  15  price_in_$                      101493 non-null  object
#  16  service_fee_in_$                101493 non-null  object
#  17  minimum_nights                  101493 non-null  float64
#  18  number of reviews               101366 non-null  float64
#  19  last review                     85959 non-null   object
#  20  reviews per month               85960 non-null   float64
#  21  review rate number              101196 non-null  float64
#  22  calculated host listings count  101174 non-null  float64
#  23  availability_365                101493 non-null  float64
#  24  house_rules                     49938 non-null   object
#  25  license                         101493 non-null  object
# dtypes: float64(9), int64(2), object(15)
# memory usage: 20.9+ MB

# %% [markdown]
# #### Converting 'Construction year' column from float to int

# %%
df['Construction year'] = df['Construction year'].astype('Int64')

# %% [markdown]
# #### Renaming Construction year column to construction_year

# %%
df = df.rename(columns={'Construction year': 'construction_year'})

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101493 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101493 non-null  int64
#  1   NAME                            101272 non-null  object
#  2   host id                         101493 non-null  int64
#  3   host_identity_verified          101493 non-null  object
#  4   host_name                       101493 non-null  object
#  5   neighbourhood_group             101493 non-null  object
#  6   neighbourhood                   101480 non-null  object
#  7   latitude                        101493 non-null  float64
#  8   longitude                       101493 non-null  float64
#  9   country                         101493 non-null  object
#  10  country_code                    101493 non-null  object
#  11  instant_bookable                101409 non-null  object
#  12  cancellation_policy             101430 non-null  object
#  13  room type                       101493 non-null  object
#  14  construction_year               101313 non-null  Int64
#  15  price_in_$                      101493 non-null  object
#  16  service_fee_in_$                101493 non-null  object
#  17  minimum_nights                  101493 non-null  float64
#  18  number of reviews               101366 non-null  float64
#  19  last review                     85959 non-null   object
#  20  reviews per month               85960 non-null   float64
#  21  review rate number              101196 non-null  float64
#  22  calculated host listings count  101174 non-null  float64
#  23  availability_365                101493 non-null  float64
#  24  house_rules                     49938 non-null   object
#  25  license                         101493 non-null  object
# dtypes: Int64(1), float64(8), int64(2), object(15)
# memory usage: 21.0+ MB

# %% [markdown]
# #### Counting all No Info rows in service_fee_in_$ column

# %%
no_info_count = df['service_fee_in_$'].value_counts().get('No Info', 0)

print(f"Number of 'No Info' rows in service_fee_in_$ column: {no_info_count}")
# Out:
# Number of 'No Info' rows in service_fee_in_$ column: 239

# %% [markdown]
# #### Dropping rows with 'No Info' value in the 'service_fee_in_$' column

# %%
df = df[df['service_fee_in_$'] != 'No Info']

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101254 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101254 non-null  int64
#  1   NAME                            101033 non-null  object
#  2   host id                         101254 non-null  int64
#  3   host_identity_verified          101254 non-null  object
#  4   host_name                       101254 non-null  object
#  5   neighbourhood_group             101254 non-null  object
#  6   neighbourhood                   101241 non-null  object
#  7   latitude                        101254 non-null  float64
#  8   longitude                       101254 non-null  float64
#  9   country                         101254 non-null  object
#  10  country_code                    101254 non-null  object
#  11  instant_bookable                101174 non-null  object
#  12  cancellation_policy             101191 non-null  object
#  13  room type                       101254 non-null  object
#  14  construction_year               101080 non-null  Int64
#  15  price_in_$                      101254 non-null  object
#  16  service_fee_in_$                101254 non-null  object
#  17  minimum_nights                  101254 non-null  float64
#  18  number of reviews               101127 non-null  float64
#  19  last review                     85744 non-null   object
#  20  reviews per month               85745 non-null   float64
#  21  review rate number              100957 non-null  float64
#  22  calculated host listings count  100935 non-null  float64
#  23  availability_365                101254 non-null  float64
#  24  house_rules                     49842 non-null   object
#  25  license                         101254 non-null  object
# dtypes: Int64(1), float64(8), int64(2), object(15)
# memory usage: 21.0+ MB

# %% [markdown]
# #### Converting 'price_in_$' column from object to int

# %%
df['price_in_$'] = df['price_in_$'].astype('Int64')

# %% [markdown]
# #### Converting 'service_fee_in_$' column from float to int

# %%
df['service_fee_in_$'] = df['service_fee_in_$'].astype('Int64')

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101254 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              101254 non-null  int64
#  1   NAME                            101033 non-null  object
#  2   host id                         101254 non-null  int64
#  3   host_identity_verified          101254 non-null  object
#  4   host_name                       101254 non-null  object
#  5   neighbourhood_group             101254 non-null  object
#  6   neighbourhood                   101241 non-null  object
#  7   latitude                        101254 non-null  float64
#  8   longitude                       101254 non-null  float64
#  9   country                         101254 non-null  object
#  10  country_code                    101254 non-null  object
#  11  instant_bookable                101174 non-null  object
#  12  cancellation_policy             101191 non-null  object
#  13  room type                       101254 non-null  object
#  14  construction_year               101080 non-null  Int64
#  15  price_in_$                      101254 non-null  Int64
#  16  service_fee_in_$                101254 non-null  Int64
#  17  minimum_nights                  101254 non-null  float64
#  18  number of reviews               101127 non-null  float64
#  19  last review                     85744 non-null   object
#  20  reviews per month               85745 non-null   float64
#  21  review rate number              100957 non-null  float64
#  22  calculated host listings count  100935 non-null  float64
#  23  availability_365                101254 non-null  float64
#  24  house_rules                     49842 non-null   object
#  25  license                         101254 non-null  object
# dtypes: Int64(3), float64(8), int64(2), object(13)
# memory usage: 21.1+ MB

# %% [markdown]
# #### Converting 'availability_365' column from float to int

# %%
df['availability_365'] = df['availability_365'].astype('Int64')

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         construction_year  price_in_$  service_fee_in_$  minimum_nights  \
# 0                    2020         966               193            10.0
# 1                    2007         142                28            30.0
# 2                    2005         620               124             3.0
# 3                    2005         368                74            30.0
# 4                    2009         204                41            10.0
# ...                   ...         ...               ...             ...
# 102594               2003         844               169             1.0
# 102595               2016         837               167             1.0
# 102596               2009         988               198             3.0
# 102597               2015         546               109             2.0
# 102598               2010        1032               206             1.0
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability_365  \
# 0                                  6.0               286
# 1                                  2.0               228
# 2                                  1.0               352
# 3                                  1.0               322
# 4                                  1.0               289
# ...                                ...               ...
# 102594                             1.0               227
# 102595                             2.0               395
# 102596                             1.0               342
# 102597                             1.0               386
# 102598                             1.0                69
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                     NaN  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                                NaN  No Licence Info
# 102597                                                NaN  No Licence Info
# 102598                                                NaN  No Licence Info
#
# [101254 rows x 26 columns]

# %% [markdown]
# #### Changing null values in 'house_rules' column to 'No Info'

# %%
df['house_rules'] = df['house_rules'].fillna('No Info')

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                221
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        13
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                     80
# cancellation_policy                  63
# room type                             0
# construction_year                   174
# price_in_$                            0
# service_fee_in_$                      0
# minimum_nights                        0
# number of reviews                   127
# last review                       15510
# reviews per month                 15509
# review rate number                  297
# calculated host listings count      319
# availability_365                      0
# house_rules                           0
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping rows where the "cancellation_policy" column is null

# %%
df.dropna(subset=['cancellation_policy'], inplace=True)

# %% [markdown]
# #### Converting 'minimum_nights' column from float to int

# %%
df['minimum_nights'] = df['minimum_nights'].astype('Int64')

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                217
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                        12
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                     17
# cancellation_policy                   0
# room type                             0
# construction_year                   167
# price_in_$                            0
# service_fee_in_$                      0
# minimum_nights                        0
# number of reviews                   127
# last review                       15501
# reviews per month                 15503
# review rate number                  297
# calculated host listings count      319
# availability_365                      0
# house_rules                           0
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping rows where the "neighbourhood" column is null

# %%
df.dropna(subset=['neighbourhood'], inplace=True)

# %% [markdown]
# #### Dropping rows where the "instant_bookable" column is null

# %%
df.dropna(subset=['instant_bookable'], inplace=True)

# %% [markdown]
# #### Dropping rows where the "construction_year" column is null

# %%
df.dropna(subset=['construction_year'], inplace=True)

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                214
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# construction_year                     0
# price_in_$                            0
# service_fee_in_$                      0
# minimum_nights                        0
# number of reviews                   126
# last review                       15479
# reviews per month                 15481
# review rate number                  281
# calculated host listings count      316
# availability_365                      0
# house_rules                           0
# license                               0
# dtype: int64

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         construction_year  price_in_$  service_fee_in_$  minimum_nights  \
# 0                    2020         966               193              10
# 1                    2007         142                28              30
# 2                    2005         620               124               3
# 3                    2005         368                74              30
# 4                    2009         204                41              10
# ...                   ...         ...               ...             ...
# 102594               2003         844               169               1
# 102595               2016         837               167               1
# 102596               2009         988               198               3
# 102597               2015         546               109               2
# 102598               2010        1032               206               1
#
#         number of reviews last review  reviews per month  review rate number  \
# 0                     9.0  10/19/2021               0.21                 4.0
# 1                    45.0   5/21/2022               0.38                 4.0
# 2                     0.0         NaN                NaN                 5.0
# 3                   270.0    7/5/2019               4.64                 4.0
# 4                     9.0  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                0.0         NaN                NaN                 3.0
# 102595                1.0    7/6/2015               0.02                 2.0
# 102596                0.0         NaN                NaN                 5.0
# 102597                5.0  10/11/2015               0.10                 3.0
# 102598                0.0         NaN                NaN                 3.0
#
#         calculated host listings count  availability_365  \
# 0                                  6.0               286
# 1                                  2.0               228
# 2                                  1.0               352
# 3                                  1.0               322
# 4                                  1.0               289
# ...                                ...               ...
# 102594                             1.0               227
# 102595                             2.0               395
# 102596                             1.0               342
# 102597                             1.0               386
# 102598                             1.0                69
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                 No Info  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                            No Info  No Licence Info
# 102597                                            No Info  No Licence Info
# 102598                                            No Info  No Licence Info
#
# [100995 rows x 26 columns]

# %% [markdown]
# #### Dropping rows where the "number of reviews" column is null

# %%
df.dropna(subset=['number of reviews'], inplace=True)

# %% [markdown]
# #### Converting 'number of reviews' column from float to int

# %%
df['number of reviews'] = df['number of reviews'].astype('Int64')

# %% [markdown]
# #### Renaming number of reviews column to number_of_reviews

# %%
df = df.rename(columns={'number of reviews': 'number_of_reviews'})

# %% [markdown]
# #### Viewing Dataframe

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         construction_year  price_in_$  service_fee_in_$  minimum_nights  \
# 0                    2020         966               193              10
# 1                    2007         142                28              30
# 2                    2005         620               124               3
# 3                    2005         368                74              30
# 4                    2009         204                41              10
# ...                   ...         ...               ...             ...
# 102594               2003         844               169               1
# 102595               2016         837               167               1
# 102596               2009         988               198               3
# 102597               2015         546               109               2
# 102598               2010        1032               206               1
#
#         number_of_reviews last review  reviews per month  review rate number  \
# 0                       9  10/19/2021               0.21                 4.0
# 1                      45   5/21/2022               0.38                 4.0
# 2                       0         NaN                NaN                 5.0
# 3                     270    7/5/2019               4.64                 4.0
# 4                       9  11/19/2018               0.10                 3.0
# ...                   ...         ...                ...                 ...
# 102594                  0         NaN                NaN                 3.0
# 102595                  1    7/6/2015               0.02                 2.0
# 102596                  0         NaN                NaN                 5.0
# 102597                  5  10/11/2015               0.10                 3.0
# 102598                  0         NaN                NaN                 3.0
#
#         calculated host listings count  availability_365  \
# 0                                  6.0               286
# 1                                  2.0               228
# 2                                  1.0               352
# 3                                  1.0               322
# 4                                  1.0               289
# ...                                ...               ...
# 102594                             1.0               227
# 102595                             2.0               395
# 102596                             1.0               342
# 102597                             1.0               386
# 102598                             1.0                69
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                 No Info  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                            No Info  No Licence Info
# 102597                                            No Info  No Licence Info
# 102598                                            No Info  No Licence Info
#
# [100869 rows x 26 columns]

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                    0
# NAME                                214
# host id                               0
# host_identity_verified                0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# country                               0
# country_code                          0
# instant_bookable                      0
# cancellation_policy                   0
# room type                             0
# construction_year                     0
# price_in_$                            0
# service_fee_in_$                      0
# minimum_nights                        0
# number_of_reviews                     0
# last review                       15410
# reviews per month                 15412
# review rate number                  281
# calculated host listings count      316
# availability_365                      0
# house_rules                           0
# license                               0
# dtype: int64

# %% [markdown]
# #### Dropping columns 'last review', 'reviews per month', 'review rate number'

# %%
df.drop(columns=['last review', 'reviews per month', 'review rate number'], inplace=True)

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         construction_year  price_in_$  service_fee_in_$  minimum_nights  \
# 0                    2020         966               193              10
# 1                    2007         142                28              30
# 2                    2005         620               124               3
# 3                    2005         368                74              30
# 4                    2009         204                41              10
# ...                   ...         ...               ...             ...
# 102594               2003         844               169               1
# 102595               2016         837               167               1
# 102596               2009         988               198               3
# 102597               2015         546               109               2
# 102598               2010        1032               206               1
#
#         number_of_reviews  calculated host listings count  availability_365  \
# 0                       9                             6.0               286
# 1                      45                             2.0               228
# 2                       0                             1.0               352
# 3                     270                             1.0               322
# 4                       9                             1.0               289
# ...                   ...                             ...               ...
# 102594                  0                             1.0               227
# 102595                  1                             2.0               395
# 102596                  0                             1.0               342
# 102597                  5                             1.0               386
# 102598                  0                             1.0                69
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                 No Info  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                            No Info  No Licence Info
# 102597                                            No Info  No Licence Info
# 102598                                            No Info  No Licence Info
#
# [100869 rows x 23 columns]

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                  0
# NAME                              214
# host id                             0
# host_identity_verified              0
# host_name                           0
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# country                             0
# country_code                        0
# instant_bookable                    0
# cancellation_policy                 0
# room type                           0
# construction_year                   0
# price_in_$                          0
# service_fee_in_$                    0
# minimum_nights                      0
# number_of_reviews                   0
# calculated host listings count    316
# availability_365                    0
# house_rules                         0
# license                             0
# dtype: int64

# %% [markdown]
# #### Changing NaN values in 'NAME' column to 'No Info'

# %%
df['NAME'] = df['NAME'].fillna('No Info')

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100869 entries, 0 to 102598
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100869 non-null  int64
#  1   NAME                            100869 non-null  object
#  2   host id                         100869 non-null  int64
#  3   host_identity_verified          100869 non-null  object
#  4   host_name                       100869 non-null  object
#  5   neighbourhood_group             100869 non-null  object
#  6   neighbourhood                   100869 non-null  object
#  7   latitude                        100869 non-null  float64
#  8   longitude                       100869 non-null  float64
#  9   country                         100869 non-null  object
#  10  country_code                    100869 non-null  object
#  11  instant_bookable                100869 non-null  object
#  12  cancellation_policy             100869 non-null  object
#  13  room type                       100869 non-null  object
#  14  construction_year               100869 non-null  Int64
#  15  price_in_$                      100869 non-null  Int64
#  16  service_fee_in_$                100869 non-null  Int64
#  17  minimum_nights                  100869 non-null  Int64
#  18  number_of_reviews               100869 non-null  Int64
#  19  calculated host listings count  100553 non-null  float64
#  20  availability_365                100869 non-null  Int64
#  21  house_rules                     100869 non-null  object
#  22  license                         100869 non-null  object
# dtypes: Int64(6), float64(3), int64(2), object(12)
# memory usage: 19.0+ MB

# %% [markdown]
# #### Dropping all rows where calculated host listings count is null

# %%
df.dropna(subset=['calculated host listings count'], inplace=True)

# %% [markdown]
# #### Renaming calculated host listings count column to calculated_host_listings_count

# %%
df = df.rename(columns={'calculated host listings count': 'calculated_host_listings_count'})

# %% [markdown]
# #### Converting 'calculated_host_listings_count' column from float to int

# %%
df['calculated_host_listings_count'] = df['calculated_host_listings_count'].astype('Int64')

# %% [markdown]
# # Finding rows where 'neighbourhood_group' is 'brookln' and rename it to 'Brooklyn'

# %%
df.loc[df['neighbourhood_group'].str.lower() == 'brookln', 'neighbourhood_group'] = 'Brooklyn'

# %% [markdown]
# #### Viewing DataFrame

# %%
df
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                           No Info
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host_name neighbourhood_group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# 1       52335172823               verified        Jenna           Manhattan
# 2       78829239556                No Info        Elise           Manhattan
# 3       85098326012            unconfirmed        Garry            Brooklyn
# 4       92037596077               verified       Lyndon           Manhattan
# ...             ...                    ...          ...                 ...
# 102594  12312296767               verified         Krik            Brooklyn
# 102595  77864383453            unconfirmed        Mifan           Manhattan
# 102596  69050334417            unconfirmed        Megan            Brooklyn
# 102597  11160591270            unconfirmed  Christopher              Queens
# 102598  68170633372            unconfirmed      Rebecca           Manhattan
#
#               neighbourhood  latitude  longitude        country country_code  \
# 0                Kensington  40.64749  -73.97237  United States           US
# 1                   Midtown  40.75362  -73.98377  United States           US
# 2                    Harlem  40.80902  -73.94190  United States           US
# 3              Clinton Hill  40.68514  -73.95976  United States           US
# 4               East Harlem  40.79851  -73.94399  United States           US
# ...                     ...       ...        ...            ...          ...
# 102594         Williamsburg  40.70862  -73.94651  United States           US
# 102595  Morningside Heights  40.80460  -73.96545  United States           US
# 102596           Park Slope  40.67505  -73.98045  United States           US
# 102597     Long Island City  40.74989  -73.93777  United States           US
# 102598      Upper West Side  40.76807  -73.98342  United States           US
#
#        instant_bookable cancellation_policy        room type  \
# 0                    no              strict     Private room
# 1                    no            moderate  Entire home/apt
# 2                   yes            flexible     Private room
# 3                   yes            moderate  Entire home/apt
# 4                    no            moderate  Entire home/apt
# ...                 ...                 ...              ...
# 102594               no            flexible     Private room
# 102595              yes            moderate     Private room
# 102596              yes            moderate     Private room
# 102597              yes              strict  Entire home/apt
# 102598               no            flexible  Entire home/apt
#
#         construction_year  price_in_$  service_fee_in_$  minimum_nights  \
# 0                    2020         966               193              10
# 1                    2007         142                28              30
# 2                    2005         620               124               3
# 3                    2005         368                74              30
# 4                    2009         204                41              10
# ...                   ...         ...               ...             ...
# 102594               2003         844               169               1
# 102595               2016         837               167               1
# 102596               2009         988               198               3
# 102597               2015         546               109               2
# 102598               2010        1032               206               1
#
#         number_of_reviews  calculated_host_listings_count  availability_365  \
# 0                       9                               6               286
# 1                      45                               2               228
# 2                       0                               1               352
# 3                     270                               1               322
# 4                       9                               1               289
# ...                   ...                             ...               ...
# 102594                  0                               1               227
# 102595                  1                               2               395
# 102596                  0                               1               342
# 102597                  5                               1               386
# 102598                  0                               1                69
#
#                                               house_rules          license
# 0       Clean up and treat the home the way you'd like...  No Licence Info
# 1       Pet friendly but please confirm with me if the...  No Licence Info
# 2       I encourage you to use my kitchen, cooking and...  No Licence Info
# 3                                                 No Info  No Licence Info
# 4       Please no smoking in the house, porch or on th...  No Licence Info
# ...                                                   ...              ...
# 102594  No Smoking No Parties or Events of any kind Pl...  No Licence Info
# 102595  House rules: Guests agree to the following ter...  No Licence Info
# 102596                                            No Info  No Licence Info
# 102597                                            No Info  No Licence Info
# 102598                                            No Info  No Licence Info
#
# [100553 rows x 23 columns]

# %% [markdown]
# #### Counting null values in all columns again

# %%
nan_counts = df.isna().sum()
print(nan_counts)
# Out:
# id                                0
# NAME                              0
# host id                           0
# host_identity_verified            0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# country                           0
# country_code                      0
# instant_bookable                  0
# cancellation_policy               0
# room type                         0
# construction_year                 0
# price_in_$                        0
# service_fee_in_$                  0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# house_rules                       0
# license                           0
# dtype: int64

# %% [markdown]
# #### Checking DataFrame column types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100553 entries, 0 to 102598
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              100553 non-null  int64
#  1   NAME                            100553 non-null  object
#  2   host id                         100553 non-null  int64
#  3   host_identity_verified          100553 non-null  object
#  4   host_name                       100553 non-null  object
#  5   neighbourhood_group             100553 non-null  object
#  6   neighbourhood                   100553 non-null  object
#  7   latitude                        100553 non-null  float64
#  8   longitude                       100553 non-null  float64
#  9   country                         100553 non-null  object
#  10  country_code                    100553 non-null  object
#  11  instant_bookable                100553 non-null  object
#  12  cancellation_policy             100553 non-null  object
#  13  room type                       100553 non-null  object
#  14  construction_year               100553 non-null  Int64
#  15  price_in_$                      100553 non-null  Int64
#  16  service_fee_in_$                100553 non-null  Int64
#  17  minimum_nights                  100553 non-null  Int64
#  18  number_of_reviews               100553 non-null  Int64
#  19  calculated_host_listings_count  100553 non-null  Int64
#  20  availability_365                100553 non-null  Int64
#  21  house_rules                     100553 non-null  object
#  22  license                         100553 non-null  object
# dtypes: Int64(7), float64(2), int64(2), object(12)
# memory usage: 19.1+ MB

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ### Data exporting

# %% [markdown]
# #### Exporting cleaned DataFrame

# %%
# Specify the relative path to save the cleaned DataFrame
relative_path_save = os.path.join('..','exported_cleaned_starting_file', 'airbnb_df_cleaned.csv')

# Construct the absolute path to save the cleaned file
absolute_path_save = os.path.abspath(relative_path_save)

# Save the cleaned DataFrame to a CSV file
df.to_csv(absolute_path_save, index=False)
